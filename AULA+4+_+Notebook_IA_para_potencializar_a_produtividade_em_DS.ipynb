# %% [markdown]
# <a href="https://colab.research.google.com/github/marcio-piagio/Aulas/blob/main/AULA%2B4%2B_%2BNotebook_IA_para_potencializar_a_produtividade_em_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook de análise para Boltfunds
#
# ![Logo Boltfunds](https://github.com/Mirlaa/energia-producao-consumo/blob/main/Logos%20-%20boltfunds/Logo%20principal%201.png?raw=true)

# %% [markdown]
# # Aula 1

# %% [markdown]
# ### Import de dados

# %%
url_resumo_mundial = 'https://raw.githubusercontent.com/alura-cursos/IA-produtividade-DS/main/Dados/Resumo_mundial.csv'
url_producao = 'https://github.com/alura-cursos/IA-produtividade-DS/raw/main/Dados/Producao_total.csv'

# %% [markdown]
# 🤖 **Prompt:**
#
# Quero que você atue como um cientista de dados e codifique para mim.
# Estou desenvolvendo um projeto de Data Science focado no tema de consumo e produção de energia elétrica pelo mundo.
#
# Tenho as url de 2 datasets no formato csv salvas no meu notebook colab. As variáveis são as seguintes: "url_resumo_mundial" e "url_producao"
#
# Escreva o código em Python para importar os dados.

# %%
import pandas as pd

# Importar o dataset de resumo mundial
resumo_mundial = pd.read_csv(url_resumo_mundial)

# Importar o dataset de produção
producao = pd.read_csv(url_producao)

# %% [markdown]
# ## Exploração de resumo_mundial

# %% [markdown]
# 🤖 **Prompt:**
#
# Agora vamos começar a trabalhar com o dataframe "resumo_mundial", escreva um código que permita executar a exploração desses dados.

# %%
# Exibir as primeiras 5 linhas do dataframe
resumo_mundial.head()
# Out:
#          data  producao_total_de_combustiveis_fosseis  \
# 0  1973-01-31                                4.932632
# 1  1973-02-28                                4.729582
# 2  1973-03-31                                4.946902
# 3  1973-04-30                                4.716271
# 4  1973-05-31                                4.956995
#
#    producao_de_energia_nuclear  producao_total_de_energia_renovavel  \
# 0                     0.068103                             0.403981
# 1                     0.064634                             0.360900
# 2                     0.072494                             0.400161
# 3                     0.064070                             0.380470
# 4                     0.062111                             0.392141
#
#    producao_total_de_energia_primaria  importacoes_de_energia_primaria  \
# 0                            5.404715                         1.173080
# 1                            5.155115                         1.168005
# ...

# %%
# Exibir as últimas 5 linhas do dataframe
resumo_mundial.tail()
# Out:
#            data  producao_total_de_combustiveis_fosseis  \
# 594  2022-07-31                                6.921426
# 595  2022-08-31                                7.047525
# 596  2022-09-30                                6.915201
# 597  2022-10-31                                7.126618
# 598  2022-11-30                                6.875368
#
#      producao_de_energia_nuclear  producao_total_de_energia_renovavel  \
# 594                     0.718109                             1.132400
# 595                     0.718526                             1.044026
# 596                     0.664673                             0.978647
# 597                     0.614741                             1.019209
# 598                     0.647029                             1.097519
#
#      producao_total_de_energia_primaria  importacoes_de_energia_primaria  \
# 594                            8.771935                         1.907862
# ...

# %%
# Exibir as estatísticas descritivas do dataframe
resumo_mundial.describe()
# Out:
#        producao_total_de_combustiveis_fosseis  producao_de_energia_nuclear  \
# count                              599.000000                   599.000000
# mean                                 5.034634                     0.519567
# std                                  0.610126                     0.202697
# min                                  3.676065                     0.062111
# 25%                                  4.683559                     0.328635
# 50%                                  4.831601                     0.594293
# 75%                                  5.087384                     0.681056
# max                                  7.126618                     0.780456
#
#        producao_total_de_energia_renovavel  \
# count                           599.000000
# mean                              0.593709
# std                               0.193351
# min                               0.304328
# 25%                               0.467414
# ...

# %%
# Exibir o tipo de dados de cada coluna do dataframe
resumo_mundial.dtypes
# Out:
# data                                                   object
# producao_total_de_combustiveis_fosseis                float64
# producao_de_energia_nuclear                           float64
# producao_total_de_energia_renovavel                   float64
# producao_total_de_energia_primaria                    float64
# importacoes_de_energia_primaria                       float64
# exportacoes_de_energia_primaria                       float64
# importacoes_liquidas_de_energia_primaria              float64
# variacao_nas_reservas_de_energia_primaria_e_outros    float64
# consumo_total_de_combustiveis_fosseis                 float64
# consumo_de_energia_nuclear                            float64
# consumo_total_de_energia_renovavel                    float64
# consumo_total_de_energia_primaria                     float64
# dtype: object

# %%
# Exibir o número de linhas e colunas do dataframe
resumo_mundial.shape
# Out:
# (599, 13)

# %%
# Exibir os nomes das colunas do dataframe
resumo_mundial.columns
# Out:
# Index(['data', 'producao_total_de_combustiveis_fosseis',
#        'producao_de_energia_nuclear', 'producao_total_de_energia_renovavel',
#        'producao_total_de_energia_primaria', 'importacoes_de_energia_primaria',
#        'exportacoes_de_energia_primaria',
#        'importacoes_liquidas_de_energia_primaria',
#        'variacao_nas_reservas_de_energia_primaria_e_outros',
#        'consumo_total_de_combustiveis_fosseis', 'consumo_de_energia_nuclear',
#        'consumo_total_de_energia_renovavel',
#        'consumo_total_de_energia_primaria'],
#       dtype='object')

# %%
# Exibir os valores únicos de cada coluna do dataframe
resumo_mundial.nunique()
# Out:
# data                                                  599
# producao_total_de_combustiveis_fosseis                599
# producao_de_energia_nuclear                           598
# producao_total_de_energia_renovavel                   599
# producao_total_de_energia_primaria                    599
# importacoes_de_energia_primaria                       599
# exportacoes_de_energia_primaria                       599
# importacoes_liquidas_de_energia_primaria              599
# variacao_nas_reservas_de_energia_primaria_e_outros    599
# consumo_total_de_combustiveis_fosseis                 599
# consumo_de_energia_nuclear                            598
# consumo_total_de_energia_renovavel                    599
# consumo_total_de_energia_primaria                     599
# dtype: int64

# %%
# Exibir a correlação entre as colunas do dataframe
resumo_mundial.corr()
# Out:
# <ipython-input-10-01bb68e681cd>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   resumo_mundial.corr()
#                                                     producao_total_de_combustiveis_fosseis  \
# producao_total_de_combustiveis_fosseis                                            1.000000
# producao_de_energia_nuclear                                                       0.411684
# producao_total_de_energia_renovavel                                               0.851062
# producao_total_de_energia_primaria                                                0.958719
# importacoes_de_energia_primaria                                                   0.051540
# exportacoes_de_energia_primaria                                                   0.925480
# ...

# %% [markdown]
# 🤖 **Prompt:**
#
# Ao usar "resumo_mundial.corr()" obtive um dataframe com os dados referentes à correlação de 12 colunas presentes no dataframe "resumo_mundial".
#
# Crie um código para visualizar a correlação em uma figura utilizando a biblioteca seaborn.

# %%
import seaborn as sns

# Obter o dataframe de correlação
correlacao = resumo_mundial.corr()

# Visualizar a correlação em uma figura
sns.heatmap(correlacao, annot=True, cmap="RdYlGn")
# Out:
# <ipython-input-11-bdae6753595d>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlacao = resumo_mundial.corr()
# <Axes: >

# %% [markdown]
# # Aula 2

# %% [markdown]
# ## Comparação de produção e consumo

# %% [markdown]
# 🤖 **Prompt:**
#
# Crie um gráfico linear que compara a produção e o consumo de energia elétrica mundial em quadrilhões de BTU.
#
# A figura deve ter o tamanho de 15 por 6, possuir com duas plotagens lineares e deve ser feita utilizando a biblioteca matplotlib.
#
# A figura deve ter no eixo X dados referentes à coluna "data" do dataframe pandas "resumo_mundial", que mostra datas no final de todos os meses durante os anos de 1973 e 2022. Esses dados não estão em datetime, estão em tipo string no formato "AAAA-MM-DD", se preciso for, transforme a coluna para datetime.
#
# No eixo Y adicione um plot para a coluna "consumo_total_de_energia_primaria" do dataframe "resumo_mundial" e um plot para a coluna "producao_total_de_energia_primaria" do dataframe "resumo_mundial".
#
# Deixe uma legenda que mostre a que se refere cada linha, se possível, deixe os dados do eixo X limpos para leitura.
#
# Adicione um título e labels para eixo X e Y que façam sentido na visualização

# %%
import matplotlib.pyplot as plt

# Transformar a coluna "data" para datetime
resumo_mundial["data"] = pd.to_datetime(resumo_mundial["data"])

# Criar um gráfico linear
plt.figure(figsize=(15, 6))
plt.plot(resumo_mundial["data"], resumo_mundial["consumo_total_de_energia_primaria"], label="Consumo de energia elétrica mundial")
plt.plot(resumo_mundial["data"], resumo_mundial["producao_total_de_energia_primaria"], label="Produção de energia elétrica mundial")

# Adicionar uma legenda
plt.legend()

# Limpar os dados do eixo X para leitura
plt.xticks(rotation=45)

# Adicionar um título e labels para eixo X e Y
plt.title("Produção e consumo de energia elétrica mundial")
plt.xlabel("Data")
plt.ylabel("Quadrilhões de BTU")

# Exibir o gráfico
plt.show()

# %% [markdown]
# Vamos ajustar essa visualização.
#
# **🤖 Prompt:**
#
# Tenho um código em python de uma plotagem de 2 gráficos em linha disponível abaixo. Preciso que as linhas do gráfico tenha a espessura de 1.8, o gráfico de consumo com a cor "#192442" e o gráfico de produção com a cor "#43D59F". Coloque os limites do eixo X a partir do valor mínimo e termine a partir do máximo. Remova a rotação dos dados no eixo X.
#
# O código:
#
# ```
# # Transformar a coluna "data" para datetime
# resumo_mundial["data"] = pd.to_datetime(resumo_mundial["data"])
#
# # Criar um gráfico linear
# plt.figure(figsize=(15, 6))
# plt.plot(resumo_mundial["data"], resumo_mundial["consumo_total_de_energia_primaria"], label="Consumo de energia elétrica mundial")
# plt.plot(resumo_mundial["data"], resumo_mundial["producao_total_de_energia_primaria"], label="Produção de energia elétrica mundial")
#
# # Adicionar uma legenda
# plt.legend()
#
# # Limpar os dados do eixo X para leitura
# plt.xticks(rotation=45)
#
# # Adicionar um título e labels para eixo X e Y
# plt.title("Produção e consumo de energia elétrica mundial")
# plt.xlabel("Data")
# plt.ylabel("Quadrilhões de BTU")
#
# # Exibir o gráfico
# plt.show()
# ```

# %%
# Transformar a coluna "data" para datetime
resumo_mundial["data"] = pd.to_datetime(resumo_mundial["data"])

# Criar um gráfico linear
plt.figure(figsize=(15, 6))
plt.plot(resumo_mundial["data"], resumo_mundial["consumo_total_de_energia_primaria"], label="Consumo de energia elétrica mundial", linewidth=1.8, color="#192442")
plt.plot(resumo_mundial["data"], resumo_mundial["producao_total_de_energia_primaria"], label="Produção de energia elétrica mundial", linewidth=1.8, color="#43D59F")

ax = plt.gca()
ax.set_xlim(min(resumo_mundial["data"]), max(resumo_mundial["data"]))

# Adicionar uma legenda
plt.legend()

# Remover a rotação dos dados no eixo X
plt.xticks(rotation=0)

# Adicionar um título e labels para eixo X e Y
plt.title("Produção e consumo de energia elétrica mundial")
plt.xlabel("Data")
plt.ylabel("Quadrilhões de BTU")

# Exibir o gráfico
plt.show()

# %% [markdown]
# ## Comparação entre os tipos de fonte

# %% [markdown]
# 🤖 **Prompt:**
#
# Crie um gráfico de barras empilhado que mostra a composição da produção de energia elétrica por fonte de energia para o ano de 2022 quadrilhões de BTU.
#
# A figura do gráfico deve ter o tamanho de 15 por 10 e deve ser feita utilizando matplotlib plt.bar.
#
# A figura deve ter no eixo X dados referentes à coluna "data" do dataframe pandas "resumo mundial", que mostra datas no final de todos os meses durante os anos de 1973 e 2022. Esses dados não estão em datetime, estão em tipo string no formato "AAAA-MM-DD", se preciso for, transforme a coluna para datetime e utilize na plotagem apenas os dados do ano de 2022.
#
# Não altere o dataframe "resumo_mundial" para filtrar a data, se for preciso, crie um novo dataframe.
#
# Para as barras, adicione os dados da coluna "producao_total_de_combustiveis_fosseis" do dataframe "resumo_mundial", "producao_de_energia_nuclear" do dataframe "resumo_mundial" e "producao_total_de_energia_renovavel" do dataframe "resumo_mundial", defina cores que se assimilam com o tipo de energia produzida
#
# Adicione um título e labels para eixo X e Y que façam sentido na visualização.

# %%
# Criar um novo dataframe com apenas os dados do ano de 2022
resumo_2022 = resumo_mundial[resumo_mundial["data"].dt.year == 2022]

# Criar um gráfico de barras empilhado
plt.figure(figsize=(15, 10))
plt.bar(resumo_2022["data"], resumo_2022["producao_total_de_combustiveis_fosseis"], color="red", label="Combustíveis fósseis")
plt.bar(resumo_2022["data"], resumo_2022["producao_de_energia_nuclear"], color="blue", label="Energia nuclear")
plt.bar(resumo_2022["data"], resumo_2022["producao_total_de_energia_renovavel"], color="green", label="Energia renovável")

# Adicionar uma legenda
plt.legend()

# Adicionar um título e labels para eixo X e Y
plt.title("Composição da produção de energia elétrica por fonte de energia para o ano de 2022")
plt.xlabel("Data")
plt.ylabel("Quadrilhões de BTU")

# Exibir o gráfico
plt.show()

# %% [markdown]
# Vamos ajustar a visualização.
#
# **🤖 Prompt:**
#
# Tenho um código em python de uma plotagem de gráficos de barra empilhados. Preciso que a largura das barras no plot seja de 15.0. A  cor da barra referente à "Combustíveis fósseis" seja da cor marrom. A ordem de plotagem das barras deve ser combustíveis fósseis, seguido de energia renovável e por fim o plot de energia nuclear. Coloque a fonte da legenda como pequena adicione um fundo na caixa de legenda.
#
# O código:
# ```
# # Criar um novo dataframe com apenas os dados do ano de 2022
# resumo_2022 = resumo_mundial[resumo_mundial["data"].dt.year == 2022]
#
# # Criar um gráfico de barras empilhado
# plt.figure(figsize=(15, 10))
# plt.bar(resumo_2022["data"], resumo_2022["producao_total_de_combustiveis_fosseis"], color="red", label="Combustíveis fósseis")
# plt.bar(resumo_2022["data"], resumo_2022["producao_de_energia_nuclear"], color="blue", label="Energia nuclear")
# plt.bar(resumo_2022["data"], resumo_2022["producao_total_de_energia_renovavel"], color="green", label="Energia renovável")
#
# # Adicionar uma legenda
# plt.legend()
#
# # Adicionar um título e labels para eixo X e Y
# plt.title("Composição da produção de energia elétrica por fonte de energia para o ano de 2022")
# plt.xlabel("Data")
# plt.ylabel("Quadrilhões de BTU")
#
# # Exibir o gráfico
# plt.show()
# ```

# %%
# Criar um gráfico de barras empilhadas
plt.figure(figsize=(15, 8))
plt.bar(resumo_2022["data"], resumo_2022["producao_total_de_combustiveis_fosseis"], color="brown", label="Combustíveis fósseis", width=15.0)
plt.bar(resumo_2022["data"], resumo_2022["producao_total_de_energia_renovavel"], color="green", label="Energia renovável", width=15.0)
plt.bar(resumo_2022["data"], resumo_2022["producao_de_energia_nuclear"], color="blue", label="Energia nuclear", width=15.0)

# Adicionar uma legenda
plt.legend(fontsize="small")

# Adicionar um título e labels para eixo X e Y
plt.title("Composição da produção de energia elétrica por fonte de energia para o ano de 2022")
plt.xlabel("Data")
plt.ylabel("Quadrilhões de BTU")

# Adicionar um fundo na caixa de legenda
plt.legend(frameon=True)

# Exibir o gráfico
plt.show()

# %% [markdown]
# #Aula 3

# %% [markdown]
# ## Exploração de produção mundial

# %% [markdown]
# 🤖 **Prompt:**
#
# Agora vamos começar a trabalhar com o dataframe "producao", escreva um código que permita executar a exploração desses dados.
# Não construa visualizações gráficas.

# %%
# Exibir as primeiras 5 linhas do dataframe
producao.head()
# Out:
#   continente          pais      1980      1981      1982      1983      1984  \
# 0     África       Argélia  2.803017  3.037537  3.224934  3.606400  3.859176
# 1     África        Angola  0.335098  0.291294  0.276262  0.395408  0.462550
# 2     África         Benin  0.000000  0.000000  0.000000  0.008960  0.015730
# 3     África      Botsuana  0.008262  0.008485  0.009242  0.008797  0.008752
# 4     África  Burkina Faso  0.000000  0.000000  0.000000  0.000000  0.000000
#
#        1985      1986      1987  ...      2013      2014      2015      2016  \
# 0  3.907466  3.968325  4.218086  ...  6.510418  6.561750  6.696193  6.910710
# 1  0.511269  0.621433  0.789429  ...  3.932204  3.802528  3.949947  3.935297
# 2  0.017930  0.017930  0.015690  ...  0.000019  0.000019  0.000056  0.000092
# 3  0.009732  0.010912  0.010845  ...  0.033335  0.038241  0.046562  0.041967
# 4  0.000000  0.000000  0.000000  ...  0.001107  0.000961  0.000988  0.001431
#
# ...

# %%
# Exibir as últimas 5 linhas do dataframe
producao.tail()
# Out:
#                    continente                      pais      1980      1981  \
# 224  América Central e do Sul         Trinidad e Tobago  0.550035  0.612443
# 225  América Central e do Sul      Ilhas Turks e Caicos  0.000000  0.000000
# 226  América Central e do Sul  Ilhas Virgens Americanas  0.000000  0.000000
# 227  América Central e do Sul                   Uruguai  0.023363  0.026342
# 228  América Central e do Sul                 Venezuela  5.766784  5.667510
#
#          1982      1983      1984      1985      1986      1987  ...  \
# 224  0.502478  0.484613  0.575515  0.610607  0.528431  0.494887  ...
# 225  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 226  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 227  0.025309  0.074850  0.073425  0.066694  0.075389  0.074871  ...
# 228  5.250659  5.032015  5.056074  4.817756  5.214786  5.171222  ...
#
#          2013      2014      2015      2016      2017      2018      2019  \
# ...

# %%
# Exibir as estatísticas descritivas do dataframe
producao.describe()
# Out:
#              1980        1981        1982        1983        1984        1985  \
# count  229.000000  229.000000  229.000000  229.000000  229.000000  229.000000
# mean     1.294072    1.272025    1.266935    1.279684    1.349113    1.382063
# std      6.397011    6.389251    6.392847    6.352637    6.716241    6.796403
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.001787    0.001589    0.002154    0.002632    0.002975    0.003040
# 75%      0.244867    0.286900    0.276262    0.314713    0.321407    0.378639
# max     67.146595   66.909508   66.526732   65.401473   68.799586   70.310670
#
#              1986        1987        1988        1989  ...        2013  \
# count  229.000000  229.000000  229.000000  229.000000  ...  229.000000
# mean     1.426948    1.460257    1.517144    1.546011  ...    2.418101
# ...

# %%
# Exibir o tipo de dados de cada coluna do dataframe
producao.dtypes
# Out:
# continente         object
# pais               object
# 1980              float64
# 1981              float64
# 1982              float64
# 1983              float64
# 1984              float64
# 1985              float64
# 1986              float64
# 1987              float64
# 1988              float64
# 1989              float64
# 1990              float64
# 1991              float64
# 1992              float64
# 1993              float64
# 1994              float64
# 1995              float64
# 1996              float64
# 1997              float64
# 1998              float64
# 1999              float64
# 2000              float64
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# 2012              float64
# ...

# %%
# Exibir o número de linhas e colunas do dataframe
producao.shape
# Out:
# (229, 45)

# %%
# Exibir os nomes das colunas do dataframe
producao.columns
# Out:
# Index(['continente', 'pais', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'producao_total'],
#       dtype='object')

# %%
# Exibir os valores únicos de cada coluna do dataframe
producao.nunique()
# Out:
# continente          7
# pais              229
# 1980              135
# 1981              136
# 1982              137
# 1983              139
# 1984              140
# 1985              142
# 1986              141
# 1987              144
# 1988              144
# 1989              144
# 1990              146
# 1991              143
# 1992              162
# 1993              166
# 1994              167
# 1995              167
# 1996              167
# 1997              169
# 1998              169
# 1999              172
# 2000              172
# 2001              174
# 2002              172
# 2003              176
# 2004              176
# 2005              180
# 2006              181
# 2007              183
# 2008              184
# 2009              185
# 2010              189
# 2011              193
# 2012              193
# 2013              192
# 2014              195
# 2015              197
# 2016              198
# 2017              201
# 2018              202
# ...

# %%
# Exibir a correlação entre as colunas do dataframe
producao.corr()
# Out:
# <ipython-input-23-e961c19e1069>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   producao.corr()
#                     1980      1981      1982      1983      1984      1985  \
# 1980            1.000000  0.998942  0.995162  0.990594  0.989672  0.983878
# 1981            0.998942  1.000000  0.996445  0.991951  0.990836  0.985025
# 1982            0.995162  0.996445  1.000000  0.998794  0.998259  0.995239
# 1983            0.990594  0.991951  0.998794  1.000000  0.999536  0.998516
# 1984            0.989672  0.990836  0.998259  0.999536  1.000000  0.999008
# 1985            0.983878  0.985025  0.995239  0.998516  0.999008  1.000000
# 1986            0.986612  0.987565  0.995547  0.998564  0.998408  0.999126
# 1987            0.983724  0.984424  0.993694  0.997575  0.997600  0.999015
# ...

# %% [markdown]
# ## Produção em nível continental

# %% [markdown]
# 🤖 **Prompt:**
#
# Tenho um dataframe chamado "producao" que contém uma coluna chamada "continente" com dados categóricos dos 7 continentes mundiais. Ele também contém a coluna "producao_total" que informa o total produzido durante 42 anos por diversos países presentes em cada continente.
#
# Crie um código que permita a construção de uma figura com um gráfico de barras horizontal (plt.barh), que compare 7 continentes com sua produção total de energia em quadrilhões de BTU.
#
# A figura do gráfico deve ter o tamanho de 7 para 7 e deve ser feita utilizando seaborn e matplotlib.
#
# Como os dados na coluna "continente" são categóricos, será preciso agrupá-los antes de enviar para a visualização.
#
# A figura deve ter no eixo X dados referentes à soma de "producao_total" para cada continente e no eixo Y os continentes referidos a cada valor.
#
# Não altere o dataframe "producao" para ajustar os dados para visualização, se for preciso, crie um novo dataframe.
#
# Adicione um título e labels para o eixo X que façam sentido na visualização.

# %%
# Agrupar os dados por continente e calcular a soma da coluna "producao_total"
producao_total = producao.groupby("continente")["producao_total"].sum()

# Criar um novo dataframe com os dados agrupados
producao_total = pd.DataFrame(producao_total)

# Criar um gráfico de barras horizontal
plt.figure(figsize=(7, 7))
plt.barh(producao_total.index, producao_total["producao_total"], color="blue")

# Adicionar um título e labels para o eixo X
plt.title("Produção total de energia por continente")
plt.xlabel("Quadrilhões de BTU")

# Exibir o gráfico
plt.show()

# %% [markdown]
# Vamos ajustar a visualização.
#
# **🤖 Prompt:**
#
# Tenho um código em python de uma plotagem de gráficos de barra horizontais que precisa ser ajustado. Preciso que o agrupamento ordene os dados do menor para o maior. Preciso que a cor do gráfico seja "#6A58CC"
#
# O código:
#
# ```
# # Agrupar os dados por continente e calcular a soma da coluna "producao_total"
# producao_total = producao.groupby("continente")["producao_total"].sum()
#
# # Criar um novo dataframe com os dados agrupados
# producao_total = pd.DataFrame(producao_total)
#
# # Criar um gráfico de barras horizontal
# plt.figure(figsize=(7, 7))
# plt.barh(producao_total.index, producao_total["producao_total"], color="blue")
#
# # Adicionar um título e labels para o eixo X
# plt.title("Produção total de energia por continente")
# plt.xlabel("Quadrilhões de BTU")
#
# # Exibir o gráfico
# plt.show()
# ```

# %%
# Agrupar os dados por continente e calcular a soma da coluna "producao_total"
producao_total = producao.groupby("continente")["producao_total"].sum()

# Ordenar os dados do menor para o maior
producao_total = producao_total.sort_values()

# Criar um novo dataframe com os dados agrupados e ordenados
producao_total = pd.DataFrame(producao_total)

# Criar um gráfico de barras horizontal
plt.figure(figsize=(7, 7))
plt.barh(producao_total.index, producao_total["producao_total"], color="#6A58CC")

# Adicionar um título e labels para o eixo X
plt.title("Produção total de energia por continente")
plt.xlabel("Quadrilhões de BTU")

# Exibir o gráfico
plt.show()

# %%
# Agrupar os dados por continente e calcular a soma da coluna "producao_total"
producao_total = producao.groupby("continente")["producao_total"].mean()

# Ordenar os dados do menor para o maior
producao_total = producao_total.sort_values()

# Criar um novo dataframe com os dados agrupados e ordenados
producao_total = pd.DataFrame(producao_total)

# Criar um gráfico de barras horizontal
plt.figure(figsize=(7, 7))
plt.barh(producao_total.index, producao_total["producao_total"], color="#6A58CC")

# Adicionar um título e labels para o eixo X
plt.title("Média da podução total de energia por continente")
plt.xlabel("Quadrilhões de BTU")

# Exibir o gráfico
plt.show()

# %%
# Agrupar os dados por continente e calcular a soma da coluna "producao_total"
producao_total = producao.groupby("continente")["producao_total"].median()

# Ordenar os dados do menor para o maior
producao_total = producao_total.sort_values()

# Criar um novo dataframe com os dados agrupados e ordenados
producao_total = pd.DataFrame(producao_total)

# Criar um gráfico de barras horizontal
plt.figure(figsize=(7, 7))
plt.barh(producao_total.index, producao_total["producao_total"], color="#6A58CC")

# Adicionar um título e labels para o eixo X
plt.title("Mediana da produção total de energia por continente")
plt.xlabel("Quadrilhões de BTU")

# Exibir o gráfico
plt.show()

# %% [markdown]
# ## Produção por países

# %% [markdown]
# 🤖 **Prompt:**
#
# Tenho um dataframe chamado "producao" que contém uma coluna chamada "pais" com dados categóricos de países mundiais. Ele também contém a coluna "producao_total" que informa o total produzido durante 42 anos por diversos países presentes em cada continente.
#
# Crie um código que permita ranquear os 10 países que mais produziram energia ao longo dos anos através dos valores em "producao_total". O rank deve estar exposto em uma tabela.
#
# Não altere o dataframe "producao" para ajustar os dados para visualização, se for preciso, crie um novo dataframe.

# %%
# Agrupar os dados por país e calcular a soma da coluna "producao_total"
producao_total = producao.groupby("pais")["producao_total"].sum()

# Criar um novo dataframe com os dados agrupados
producao_total = pd.DataFrame(producao_total)

# Ordenar os dados pelo valor da coluna "producao_total" em ordem decrescente
producao_total = producao_total.sort_values("producao_total", ascending=False)

# Selecionar as primeiras 10 linhas do dataframe
producao_total = producao_total.head(10)

# Exibir o dataframe
producao_total
# Out:
#                         producao_total
# pais
# Estados Unidos             3149.020415
# China                      2620.639503
# Rússia                     1549.828759
# Arábia Saudita              905.009573
# Antiga União Soviética      840.491586
# Canadá                      709.974346
# Irã                         452.576902
# Austrália                   423.582598
# Índia                       421.527874
# Indonésia                   372.069227

# %% [markdown]
# ### Dados atuais

# %% [markdown]
# 🤖 **Prompt:**
#
# Tenho um dataframe chamado "producao" que contém uma coluna chamada "pais" com dados categóricos de países mundiais. O dataframe "producao" também tem 42 colunas que vão de "1980" até "2021" que registram o total de energia produzida naquele ano.
#
# Crie um código que some o total de energia produzida nos anos de "2007","2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021" por cada país e retorne uma tabela com um Rank dos 10 países que mais produziram energia durante esses anos.
#
# Não altere o dataframe "producao" para ajustar os dados, se for preciso, crie um novo dataframe.

# %%
# Criar um novo dataframe com apenas os anos de "2007","2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021"
producao_anos = producao[["pais", "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021"]]

# Somar o total de energia produzida em cada país
producao_anos["producao_total"] = producao_anos[["2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021"]].sum(axis=1)

# Ordenar os dados pelo valor da coluna "producao_total" em ordem decrescente
producao_anos = producao_anos.sort_values("producao_total", ascending=False)

# Selecionar as primeiras 10 linhas do dataframe
producao_anos = producao_anos.head(10).round(2)

# Exibir o dataframe
producao_anos[['pais','producao_total']]
# Out:
# <ipython-input-29-8adf1068b57a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   producao_anos["producao_total"] = producao_anos[["2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021"]].sum(axis=1)
#                pais  producao_total
# 123           China         1627.55
# 183  Estados Unidos         1271.14
# 65           Rússia          867.13
# 174  Arábia Saudita          401.80
# 179          Canadá          311.06
# 130           Índia          231.95
# 165             Irã          227.89
# 117       Austrália          224.64
# 131       Indonésia          207.31
# 191          Brasil          163.53

# %% [markdown]
# # Aula 4

# %% [markdown]
# ## Histórico de produções por países

# %% [markdown]
# 🤖 **Prompt:**
#
# Estou analisando um dataframe chamado "producao_anos" que contém dados de produção de energia durante 15 anos de 10 países.
#
# O dataframe "producao_anos" tem colunas dadas por "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021", que mostram a energia produzida nos anos informados.
#
# No dataframe "producao_anos" também tem a coluna "pais" que armazena com dados categóricos com o nome de 10 países.
#
# Outras colunas que também fazem parte do dataframe "producao_anos", como "continente" e "producao_total", mas não são de interesse para a análise, então busque removê-las da visualização
#
# Desejo verificar o histórico de produção de cada um dos países durante os anos.
#
# Crie uma plotagem com a biblioteca plotly graph_objects de forma que seja possível observar a sequência de energia produzida em quadrilhões de BTU por ano em cada um dos 10 países.
#
# No eixo X deve conter os dados de cada um dos anos definidos nas colunas "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021". Não existe uma coluna contendo todos os anos, então ajuste os dados para a visualização.
#
# No eixo Y deve conter a produção de energia, e cada linha no gráfico deve se referir a um país.
#
# Não altere o dataframe "producao_anos" para ajustar os dados, se for preciso, crie um novo dataframe.

# %%
import plotly.graph_objects as go

# 1. Criar um novo DataFrame com as colunas de interesse
colunas_anos = ["2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021"]
producao_pais = producao_anos[colunas_anos + ["pais"]]

# 2. Criar a plotagem usando plotly.graph_objects
fig = go.Figure()

for pais in producao_pais["pais"]:
    dados_pais = producao_pais[producao_pais["pais"] == pais]
    fig.add_trace(go.Scatter(
        x=colunas_anos,
        y=dados_pais[colunas_anos].values.tolist()[0],
        mode='lines+markers',
        name=pais
    ))

fig.update_layout(
    title='Histórico de Produção de Energia por País (2007-2021)',
    xaxis_title='Ano',
    yaxis_title='Produção de Energia (quadrilhões de BTU)',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Vamos ajustar a visualização
#
# **🤖 Prompt:**
#
# Tenho um código em python de uma plotagem de gráficos de linha com plotly que precisa ser ajustado. Nele eu preciso que seja removido os marcadores que colocam pontos no gráfico. Preciso também que o fundo do gráfico seja branco. Realize esses ajustes no código.
#
# O código:
#
# ```
# import plotly.graph_objects as go
#
# # 1. Criar um novo DataFrame com as colunas de interesse
# colunas_anos = ["2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021"]
# producao_pais = producao_anos[colunas_anos + ["pais"]]
#
# # 2. Criar a plotagem usando plotly.graph_objects
# fig = go.Figure()
#
# for pais in producao_pais["pais"]:
#     dados_pais = producao_pais[producao_pais["pais"] == pais]
#     fig.add_trace(go.Scatter(
#         x=colunas_anos,
#         y=dados_pais[colunas_anos].values.tolist()[0],
#         mode='lines+markers',
#         name=pais
#     ))
#
# fig.update_layout(
#     title='Histórico de Produção de Energia por País (2007-2021)',
#     xaxis_title='Ano',
#     yaxis_title='Produção de Energia (quadrilhões de BTU)',
# )
#
# fig.show()
# ```

# %%
import plotly.graph_objects as go

# 1. Criar um novo DataFrame com as colunas de interesse
colunas_anos = ["2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021"]
producao_pais = producao_anos[colunas_anos + ["pais"]]

# 2. Criar a plotagem usando plotly.graph_objects
fig = go.Figure()

for pais in producao_pais["pais"]:
    dados_pais = producao_pais[producao_pais["pais"] == pais]
    fig.add_trace(go.Scatter(
        x=colunas_anos,
        y=dados_pais[colunas_anos].values.tolist()[0],
        mode='lines',  # Remover 'markers' para remover os pontos
        name=pais
    ))

fig.update_layout(
    title='Histórico de Produção de Energia por País (2007-2021)',
    xaxis_title='Ano',
    yaxis_title='Produção de Energia (quadrilhões de BTU)',
    plot_bgcolor='white'  # Definir o fundo do gráfico como branco
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Tendência de produção por fonte

# %% [markdown]
# 🤖 **Prompt:**
#
# Quero que você atue como um cientista de dados e codifique para mim. Estou desenvolvendo um projeto de Data Science focado no tema de consumo e produção de energia elétrica pelo mundo. Agora preciso verificar a tendência de produção de energia por 3 tipos diferentes de fontes de energia.
#
# No dataframe "resumo_mundial" existem 3 colunas que se caracterizam por serem séries temporais chamadas "producao_total_de_combustiveis_fosseis", "producao_de_energia_nuclear" e "producao_total_de_energia_renovavel".
#
# Existe outra coluna em "resumo_mundial" chamada "data" que tem datas em intervalos fixos em cada linha, mostrando o final de todos os meses durante os anos de 1973 e 2022.
#
# Não altere o dataframe "resumo_mundial" para ajustar os dados, se for preciso, crie um novo dataframe.
#
# Crie um código que plote a tendência dos valores de cada tipo de produção ao longo dos anos. Utilize a biblioteca "statsmodels" para encontrar a tendência das séries com "seasonal_decompose".
#
# Ao fim, crie uma plotagem com a série temporal de cada um dos tipos de produção com plotly. Adicione título e legenda que façam sentido.

# %%
import statsmodels.api as sm

# 2. Criar um novo DataFrame com as colunas de interesse
producao_tipos = resumo_mundial[["data", "producao_total_de_combustiveis_fosseis", "producao_de_energia_nuclear", "producao_total_de_energia_renovavel"]]

# 3. Utilizar seasonal_decompose para decompor as séries temporais
producao_tipos.set_index("data", inplace=True)
decomposed_combustiveis = sm.tsa.seasonal_decompose(producao_tipos["producao_total_de_combustiveis_fosseis"], model='additive')
decomposed_nuclear = sm.tsa.seasonal_decompose(producao_tipos["producao_de_energia_nuclear"], model='additive')
decomposed_renovavel = sm.tsa.seasonal_decompose(producao_tipos["producao_total_de_energia_renovavel"], model='additive')

# 4. Criar a plotagem usando plotly
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=producao_tipos.index,
    y=decomposed_combustiveis.trend,
    mode='lines',
    name='Produção de Combustíveis Fósseis (Tendência)'
))


fig.add_trace(go.Scatter(
    x=producao_tipos.index,
    y=decomposed_nuclear.trend,
    mode='lines',
    name='Produção de Energia Nuclear (Tendência)'
))


fig.add_trace(go.Scatter(
    x=producao_tipos.index,
    y=decomposed_renovavel.trend,
    mode='lines',
    name='Produção de Energia Renovável (Tendência)'
))

fig.update_layout(
    title='Tendência de Produção de Energia por Tipo',
    xaxis_title='Data',
    yaxis_title='Produção de Energia',
    legend_title='Tipo de Produção',
    plot_bgcolor='white'  # Definir o fundo do gráfico como branco
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
